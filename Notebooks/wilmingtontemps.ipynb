# %%
# Importing libraries
import hvplot.pandas
import pandas as pd

# %%
# Define the URL for NC mean temperature data download

nc_temp_url = (
    'https://www.ncei.noaa.gov/access/monitoring/climate-at-a-glance/city/time'
    '-series/USW00013748/tmax/12/12/1943-2023.csv')
nc_temp_url
# Out:
# 'https://www.ncei.noaa.gov/access/monitoring/climate-at-a-glance/city/time-series/USW00013748/tmax/12/12/1943-2023.csv'

# %%
# Import NC temperature values from NCEI

nc_temp_df = pd.read_csv(
    nc_temp_url, header=3, names=['year', 'temperature_f'])
nc_temp_df
# Out:
#       year  temperature_f
# 0   194812           75.1
# 1   194912           76.2
# 2   195012           75.3
# 3   195112           75.8
# 4   195212           75.4
# ..     ...            ...
# 70  201812           75.7
# 71  201912           76.7
# 72  202012           76.0
# 73  202112           75.9
# 74  202212           76.0
#
# [75 rows x 2 columns]

# %%
# Extract the year from the date

nc_temp_df.year = pd.to_datetime(nc_temp_df.year, format='%Y%m').dt.year

nc_temp_df
# Out:
#     year  temperature_f
# 0   1948           75.1
# 1   1949           76.2
# 2   1950           75.3
# 3   1951           75.8
# 4   1952           75.4
# ..   ...            ...
# 70  2018           75.7
# 71  2019           76.7
# 72  2020           76.0
# 73  2021           75.9
# 74  2022           76.0
#
# [75 rows x 2 columns]

# %%
# Compute celsius temperatures

nc_temp_df['temperature_c'] = (nc_temp_df['temperature_f'] - 32) * 5 / 9
nc_temp_df
# Out:
#     year  temperature_f  temperature_c
# 0   1948           75.1      23.944444
# 1   1949           76.2      24.555556
# 2   1950           75.3      24.055556
# 3   1951           75.8      24.333333
# 4   1952           75.4      24.111111
# ..   ...            ...            ...
# 70  2018           75.7      24.277778
# 71  2019           76.7      24.833333
# 72  2020           76.0      24.444444
# 73  2021           75.9      24.388889
# 74  2022           76.0      24.444444
#
# [75 rows x 3 columns]

# %%
# Plot the NC temperature data over time

nc_temp_df.hvplot(
    x='year', y='temperature_f',
    title='Maximum Annual Temperature in Wilmington, NC, USA',
    xlabel='Year', ylabel='Temperature(F)')
# Out:
# /opt/conda/lib/python3.10/site-packages/holoviews/core/data/pandas.py:39: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return dataset.data.dtypes[idx].type
# /opt/conda/lib/python3.10/site-packages/holoviews/core/data/pandas.py:39: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return dataset.data.dtypes[idx].type
# :Curve   [year]   (temperature_f)

# %%
# %%capture
# %%bash
jupyter nbconvert wilmingtontemps.ipynb --to html --no-input
